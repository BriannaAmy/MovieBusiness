# %%
import requests
import json
from config import api_key
from pprint import pprint
import pandas as pd
import csv
import time

# %%
# Configuration of API variables
url = "http://www.omdbapi.com/?t="
api_key = "&apikey=" + api_key

# Query each movie title and populate variables
with open("Resources/MovieList.csv", "r") as file:
    
    movies = file.readlines()
    
    #variable lists creation
    movieTitle = []
    genre = []
    runtime = []
    boxOffice = []
    metaRating = []
    imdbRating = []
    releaseYear = []
    
    for movie in movies:
    
        movie = movie.replace(" ","+")
        queryURL = url + movie + api_key
        
        try:
            
            response = requests.get(queryURL).json()
            
            # create variables for Data Frame
            movieTitle.append(response.get('Title', 'N/A'))
            genre.append(response.get('Genre', 'N/A'))
            runtime.append(response.get('Runtime', 'N/A'))
            boxOffice.append(response.get('BoxOffice', 'N/A'))
            metaRating.append(response.get('Metascore', 'N/A'))
            imdbRating.append(response.get('imdbRating', 'N/A'))
            releaseYear.append(response.get('Year', 'N/A'))
            
        except:
            print(f"{movie} not found...skipping")
            pass
        
        time.sleep(2)
        
#populate data frame
movieDataDF = pd.DataFrame({
    "Movie Title": movieTitle,
    "Genre": genre,
    "Runtime (min)": runtime,
    "Box Office ($)": boxOffice,
    "Metacritic Rating": metaRating,
    "IMDb Rating": imdbRating,
    "Release Year": releaseYear
})

movieDataDF.head()
# Out:
# ï»¿Movie+Title
#  not found...skipping
# All+Woman
#  not found...skipping
# Nocturne
#  not found...skipping
# National+Lampoon+Presents+Dorm+Daze
#  not found...skipping
# Hushâ€¦+Hush
#  not found...skipping
# The+War+at+Home
#  not found...skipping
# The+Devil+and+Daniel+Webster
#  not found...skipping
# The+Fighting+Seventh
#  not found...skipping
# The+Cheat
#  not found...skipping
# Three+Cheers+for+the+Irish
#  not found...skipping
# Wildfire
#  not found...skipping
# The+Lion+Man
#  not found...skipping
# The+Shadow+of+the+Desert
#  not found...skipping
# Cancer+Wars
#  not found...skipping
# What's+Wrong+with+Virginia
#  not found...skipping
# Cigarrette+Girl
#  not found...skipping
# For+All+Mankind
#  not found...skipping
# A+Modern+Twain+Story:+The+Prince+and+the+Pauper
#  not found...skipping
# Berkeley+Square
#  not found...skipping
# The+House+Across+the+Street
#  not found...skipping
# Cheap+Thrills+(film)
#  not found...skipping
# L.I.E.
#  not found...skipping
# ...

# %%
print(len(movieTitle))
print(len(genre))
print(len(runtime))
print(len(boxOffice))
print(len(metaRating))
print(len(imdbRating))
print(len(releaseYear))
# Out:
# 978
# 978
# 978
# 960
# 960
# 960
# 960
